# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Assignment2_DL/Assignment2/
# Out:
# /content/drive/MyDrive/Assignment2_DL/Assignment2

# %%
# %ls
# Out:
# Assignment2.pdf     experiment_a.py                project_plan.md
# checkpoints/        experiment_b.py                __pycache__/
# colab_runner.py     experiment_feature_perturb.py  requirements.txt
# data/               main.ipynb                     train_baseline.py
# data_loader.py      models/                        visualize_boundaries.py
# evaluate_models.py  optimize_corruption.py         visualize_tsne.py

# %%
# Install required libraries
# %pip install -r requirements.txt

# %%
from colab_runner import AssignmentRunner

# Instantiate our Master pipeline architecture (You can change 'cifar10' to 'fmnist')
runner = AssignmentRunner(dataset_name='cifar10', batch_size=128, base_epochs=15)

# %%
# runner.train_baseline(model_name='resnet')
runner.train_baseline(model_name='vgg')
# Out:
# [Running Phase 2 | VGG Baseline]
# Training vgg on cifar10 using computing device: cuda
# [CIFAR10] Data Loaded:
#  - Train samples: 40000
#  - Val samples:   10000
#  - Test samples:  10000
#
# Epoch 1/15
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_15172/1452853433.py in <cell line: 0>()
#       1 # runner.train_baseline(model_name='resnet')
# ----> 2 runner.train_baseline(model_name='vgg')
#
# /content/colab_runner.py in train_baseline(self, model_name, lr)
#      33         print(f"\n[Running Phase 2 | {model_name.upper()} Baseline]")
#      34         try:
# ---> 35             train_baseline(model_name, self.dataset_name, epochs=self.base_epochs, batch_size=self.batch_size, lr=lr)
#      36         finally:
#      37             self._cleanup_memory()
#
# ...
